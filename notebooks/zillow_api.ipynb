# %%
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import requests

# %%
url = "https://zillow56.p.rapidapi.com/search"

querystring = {"location":"Denver, CO"}

headers = {
	"X-RapidAPI-Key": "2371e7da0dmsh9eb69d12a41c0d2p10930fjsn51a74485e511",
	"X-RapidAPI-Host": "zillow56.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"results":[{"bathrooms":3.0,"bedrooms":2.0,"city":"Denver","comingSoonOnMarketDate":1668038400000,"country":"USA","currency":"USD","daysOnZillow":-1,"homeStatus":"FOR_SALE","homeStatusForHDP":"FOR_SALE","homeType":"TOWNHOUSE","isFeatured":false,"isNonOwnerOccupied":true,"isPreforeclosureAuction":false,"isPremierBuilder":false,"isUnmappable":false,"isZillowOwned":false,"latitude":39.74711,"listing_sub_type":{"is_comingSoon":true},"livingArea":1637.0,"longitude":-105.02884,"lotAreaUnit":"sqft","lotAreaValue":1479.0,"price":824000.0,"priceForHDP":824000.0,"rentZestimate":3549,"shouldHighlight":false,"state":"CO","streetAddress":"1933 N Hooker Street","taxAssessedValue":581900.0,"zestimate":748300,"zipcode":"80204","zpid":251841264},{"bathrooms":4.0,"bedrooms":4.0,"city":"Denver","comingSoonOnMarketDate":1667952000000,"country":"USA","currency":"USD","daysOnZillow":-1,"homeStatus":"FOR_SALE","homeStatusForHDP":"FOR_SALE","homeType":"SINGLE_FAMILY","isFeatured":false,"isNonOwnerOccupied":true,"isPreforeclosureAuction":false,"isPremierBuilder":false,"isUnmappable":false,"isZillowOwned":false,"latitude":39.77069,"listing_sub_type":{"is_comingSoon":true},"livingArea":3000.0,"longitude":-105.03899,"lotAreaUnit":"sqft","lotAreaValue":4769.0,"price":1399999.0,"priceForHDP":1399999.0,"rentZestimate":5438,"shouldHighlight":false,"state":"CO","streetAddress":"3862 Perry Street","taxAssessedValue":1003800.0,"zestimate":1396500,"zipcode":"80212","zpid":121237597},{"bathrooms":2.0,"bedrooms":4.0,"city":"Denver","comingSoonOnMarketDate":1667952000000,"country":"USA","currency":"USD","daysOnZillow":-1,"homeStatus":"FOR_SALE","homeStatusForHDP":"FOR_SALE","homeType":"SINGLE_FAMILY","isFeatured":false,"isNonOwnerOccupied":true,"isPreforeclosureAuction":false,"isPremierBuilder":false,"isUnmappable":false,"isZillowOwned":false,"latitude":39.760395,"listing_sub_type":{"is_comingSoon":true},"livingArea":1500.0,"longitude":-104.906746,"lotAreaUnit":"sqft","lotAreaValue":6620.0,"price":579000.0,"priceForHDP":579000.0,"rentZestimate":2600,"shouldHighlight":false,"state":"CO","streetAddress":"3000 Olive Street","taxAssessedValue":445200.0,"zestimate":572600,"zipcode":"80207","zpid":13281982},{"bathrooms":3.0,"bedrooms":3.0,"city":"Denver","comingSoonOnMarketDate":1668038400000,"country":"USA","currency":"USD","daysOnZillow":-1,"homeStatus":"FOR_SALE","homeStatusForHDP":"FOR_SALE","homeType":"TOWNHOUSE","isFeatured":false,"isNonOwnerOccupied":true,"isPreforeclosureAuction":false,"isPremierBuilder":false,"isUnmappable":false,"isZillowOwned":false,"latitude":39.762276,"listing_sub_type":{"is_comingSoon":true},"livingArea":2616.0,"longitude":-105.01565,"lotAreaUnit":"sqft","lotAreaValue":2204.0,"price":1550000.0,"priceForHDP":1550000.0,"rentZestimate":4500,"shouldHighlight":false,"state":"CO","streetAddress":"3220 Zuni Street","taxAssessedValue":773800.0,"zipcode":"80211","zpid":123601127},{"bathrooms":2.0,"bedrooms":2.0,"city":"Denver","country":"USA","currency":"USD","daysOnZillow":-1,"homeStatus":"FOR_SALE","homeStatusForHDP":"FOR_SALE","homeType":"TOWNHOUSE","isFeatured":false,"isNonOwnerOccupied":true,"isPreforeclosureAuction":false,"isPremierBuilder":false,"isUnmappable":false,"isZillowOwned":false,"latitude":39.68501,"listing_sub_type":{"is_FSBA":true},"livingArea":1595.0,"longitude":-104.896996,"price":361000.0,"priceForHDP":361000.0,"rentZestimate":1995,"shouldHighlight":false,"state":"CO","streetAddress":"1699 S Trenton Street  Unit 160","taxAssessedValue":255500.0,"unit":"Unit 160","zestimate":331900,"zipcode":"80231","zpid":13410239},{"bathrooms":3.0,"bedrooms":3.0,"city":"Denver","country":"USA","currency":"USD","daysOnZillow":-1,"homeStatus":"FOR_SALE","homeStatusForHDP":"FOR_SALE","homeType":"SINGLE_FAMILY","isFeatured":false,"isNonOwnerOccupied":true,"isPreforeclosureAuction":false,"isPremierBuilder":false,"isUnmappable":false,"isZillowOwned":false,"latitude":39.774685,"listing_sub_type":{"is_FSBA":true},"livingArea":1417.0,"longitude":-104.7 ...

# %%
soup = BeautifulSoup(response.text, "xml")

# %%
print(soup.prettify())
# Out:
# <?xml version="1.0" encoding="utf-8"?>

# %%
print(soup.find('zestimate').prettify())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 print(soup.find('zestimate').prettify())
#
# AttributeError: 'NoneType' object has no attribute 'prettify'
